# %%
## Make plot of BAT Fluence vs XRT 500 s fluence for sGRBs
## Convert to GTM & WFI bands
## Overplot WFI sensitivities and GW170817 fluence

# %%
import numpy as np
import matplotlib.pylab as plot
import grb_catalogs
import fit_lc

# %%
bat=grb_catalogs.load_BAT()
grbox=grb_catalogs.load_GRBOX()
xrt=fit_lc.load_data(dir='/Users/jracusin/Swift/GRBfits/GRBs/')[1]
# Out:
# downloading:  http://www.swift.ac.uk/xrt_curves/00160672/curve.qdp
# /Users/jracusin/Swift/GRBfits/GRBs/GRB051021B/curve.qdp
# downloading:  http://www.swift.ac.uk/xrt_curves/00020019/curve.qdp
# /Users/jracusin/Swift/GRBfits/GRBs/GRB051022/curve.qdp
# downloading:  http://www.swift.ac.uk/xrt_curves/00020019/WTCURVE.qdp
# /Users/jracusin/Swift/GRBfits/GRBs/GRB051022/WTCURVE.qdp
# downloading:  http://www.swift.ac.uk/xrt_curves/00020019/WTUL.qdp
# /Users/jracusin/Swift/GRBfits/GRBs/GRB051022/WTUL.qdp
# downloading:  http://www.swift.ac.uk/xrt_curves/00020020/curve.qdp
# /Users/jracusin/Swift/GRBfits/GRBs/GRB051028/curve.qdp
# downloading:  http://www.swift.ac.uk/xrt_curves/00020020/WTCURVE.qdp
# /Users/jracusin/Swift/GRBfits/GRBs/GRB051028/WTCURVE.qdp
# downloading:  http://www.swift.ac.uk/xrt_curves/00020020/WTUL.qdp
# /Users/jracusin/Swift/GRBfits/GRBs/GRB051028/WTUL.qdp
# downloading:  http://www.swift.ac.uk/xrt_curves/00163136/curve.qdp
# ...
